# %%
import pandas as pd

""" La función  load_data sirve para cargar el csv

"""

def load_data(file):
    df = pd.read_csv(file)
    return df

datacrash = load_data('Airplane_Crashes.csv')

datacrash.head()
# Out:
#          Date   Time                            Location  \
# 0  09/17/1908  17:18                 Fort Myer, Virginia
# 1  07/12/1912  06:30             AtlantiCity, New Jersey
# 2  08/06/1913    NaN  Victoria, British Columbia, Canada
# 3  09/09/1913  18:30                  Over the North Sea
# 4  10/17/1913  10:30          Near Johannisthal, Germany
#
#                  Operator Flight #          Route                    Type  \
# 0    Military - U.S. Army      NaN  Demonstration        Wright Flyer III
# 1    Military - U.S. Navy      NaN    Test flight               Dirigible
# 2                 Private        -            NaN        Curtiss seaplane
# 3  Military - German Navy      NaN            NaN  Zeppelin L-1 (airship)
# 4  Military - German Navy      NaN            NaN  Zeppelin L-2 (airship)
#
#   Registration cn/In  Aboard  Fatalities  Ground  \
# 0          NaN     1     2.0         1.0     0.0
# 1          NaN   NaN     5.0         5.0     0.0
# 2          NaN   NaN     1.0         1.0     0.0
# 3          NaN   NaN    20.0        14.0     0.0
# 4          NaN   NaN    30.0        30.0     0.0
#
#                                              Summary
# 0  During a demonstration flight, a U.S. Army fly...
# 1  First U.S. dirigible Akron exploded just offsh...
# 2  The first fatal airplane accident in Canada oc...
# 3  The airship flew into a thunderstorm and encou...
# 4  Hydrogen gas which was being vented was sucked...

# %%
column_to_drop = (datacrash.isnull().sum()/len(datacrash))
print(column_to_drop)
# Out:
# Date            0.000000
# Time            0.421222
# Location        0.003797
# Operator        0.003417
# Flight #        0.797077
# Route           0.323842
# Type            0.005125
# Registration    0.063591
# cn/In           0.233106
# Aboard          0.004176
# Fatalities      0.002278
# Ground          0.004176
# Summary         0.074032
# dtype: float64

# %%
"""
def drop_null(df,percent):
    for column in df:
        column_to_drop = (df.isnull().sum()/len(df))
        for value in column_to_drop:
            if value in column >= percent:
                del df[column]
        
    return df
        
datacrash = drop_null(datacrash,0.75)
datacrash.head()

"""
# Out:
# '\ndef drop_null(df,percent):\n    for column in df:\n        column_to_drop = (df.isnull().sum()/len(df))\n        for value in column_to_drop:\n            if value in column >= percent:\n                del df[column]\n        \n    return df\n        \ndatacrash = drop_null(datacrash,0.75)\ndatacrash.head()\n\n'

# %%
def split_column(df,col):
    df['new_column'] = df[col].str.split(',').str[-1]
    df['new_column2'] = df[col].str.split(',').str[0]
    return df

datacrash = split_column(datacrash,'Location')

datacrash.head()
# Out:
#          Date   Time                            Location  \
# 0  09/17/1908  17:18                 Fort Myer, Virginia
# 1  07/12/1912  06:30             AtlantiCity, New Jersey
# 2  08/06/1913    NaN  Victoria, British Columbia, Canada
# 3  09/09/1913  18:30                  Over the North Sea
# 4  10/17/1913  10:30          Near Johannisthal, Germany
#
#                  Operator Flight #          Route                    Type  \
# 0    Military - U.S. Army      NaN  Demonstration        Wright Flyer III
# 1    Military - U.S. Navy      NaN    Test flight               Dirigible
# 2                 Private        -            NaN        Curtiss seaplane
# 3  Military - German Navy      NaN            NaN  Zeppelin L-1 (airship)
# 4  Military - German Navy      NaN            NaN  Zeppelin L-2 (airship)
#
#   Registration cn/In  Aboard  Fatalities  Ground  \
# 0          NaN     1     2.0         1.0     0.0
# 1          NaN   NaN     5.0         5.0     0.0
# 2          NaN   NaN     1.0         1.0     0.0
# 3          NaN   NaN    20.0        14.0     0.0
# 4          NaN   NaN    30.0        30.0     0.0
#
#                                              Summary          new_column  \
# 0  During a demonstration flight, a U.S. Army fly...            Virginia
# 1  First U.S. dirigible Akron exploded just offsh...          New Jersey
# 2  The first fatal airplane accident in Canada oc...              Canada
# 3  The airship flew into a thunderstorm and encou...  Over the North Sea
# 4  Hydrogen gas which was being vented was sucked...             Germany
#
#           new_column2
# 0           Fort Myer
# 1         AtlantiCity
# 2            Victoria
# 3  Over the North Sea
# 4   Near Johannisthal

# %%
def rename_col(df,old_name,new_name):
    return df.rename(columns = {'old_name':'new_name'},inplace = True)
datacrash = rename_col(datacrash,'new_column','country')
datacrash.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-102-4d521173b095> in <module>
#       1 def rename_col(df,old_name,new_name):
#       2     return df.rename(columns = {'old_name':'new_name'},inplace = True)
# ----> 3 datacrash = rename_col(datacrash,'new_column','country')
#       4 datacrash.head()
#
# <ipython-input-102-4d521173b095> in rename_col(df, old_name, new_name)
#       1 def rename_col(df,old_name,new_name):
# ----> 2     return df.rename(columns = {'old_name':'new_name'},inplace = True)
#       3 datacrash = rename_col(datacrash,'new_column','country')
#       4 datacrash.head()
#
# AttributeError: 'NoneType' object has no attribute 'rename'

# %%
def percent(df,col,column):
    df['percent'] = ((df[col]/df[column])*100)
    return df

datacrash = percent(datacrash,'Fatalities','Aboard')

datacrash.head()
# Out:
#          Date   Time                            Location  \
# 0  09/17/1908  17:18                 Fort Myer, Virginia
# 1  07/12/1912  06:30             AtlantiCity, New Jersey
# 2  08/06/1913    NaN  Victoria, British Columbia, Canada
# 3  09/09/1913  18:30                  Over the North Sea
# 4  10/17/1913  10:30          Near Johannisthal, Germany
#
#                  Operator Flight #          Route                    Type  \
# 0    Military - U.S. Army      NaN  Demonstration        Wright Flyer III
# 1    Military - U.S. Navy      NaN    Test flight               Dirigible
# 2                 Private        -            NaN        Curtiss seaplane
# 3  Military - German Navy      NaN            NaN  Zeppelin L-1 (airship)
# 4  Military - German Navy      NaN            NaN  Zeppelin L-2 (airship)
#
#   Registration cn/In  Aboard  Fatalities  Ground  \
# 0          NaN     1     2.0         1.0     0.0
# 1          NaN   NaN     5.0         5.0     0.0
# 2          NaN   NaN     1.0         1.0     0.0
# 3          NaN   NaN    20.0        14.0     0.0
# 4          NaN   NaN    30.0        30.0     0.0
#
#                                              Summary          new_column  \
# 0  During a demonstration flight, a U.S. Army fly...            Virginia
# 1  First U.S. dirigible Akron exploded just offsh...          New Jersey
# 2  The first fatal airplane accident in Canada oc...              Canada
# 3  The airship flew into a thunderstorm and encou...  Over the North Sea
# 4  Hydrogen gas which was being vented was sucked...             Germany
#
#           new_column2  percent
# 0           Fort Myer     50.0
# 1         AtlantiCity    100.0
# 2            Victoria    100.0
# 3  Over the North Sea     70.0
# 4   Near Johannisthal    100.0

# %%
"""
def values(df,col):
    return df[col].value_counts()

values(datacrash,'new_column')
"""
# Out:
# "\ndef values(df,col):\n    return df[col].value_counts()\n\nvalues(datacrash,'new_column')\n"

# %%
"""
def filtered(df,column,value):
    df_filtered = df[(df[column].value_count() > value)]
    return df
datacrash = filtered(datacrash,'new_column','100')
"""
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-a56eedefc76f> in <module>
#       2     df_filtered = df[(df[column].value_count() > value)]
#       3     return df
# ----> 4 datacrash = filtered(datacrash,'new_column','100')
#
# <ipython-input-16-a56eedefc76f> in filtered(df, column, value)
#       1 def filtered(df,column,value):
# ----> 2     df_filtered = df[(df[column].value_count() > value)]
#       3     return df
#       4 datacrash = filtered(datacrash,'new_column','100')
#
# /usr/lib/python3/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'value_count'

# %%
def filter(df,col):
    crashes = df[col].value_counts()
    return (crashes.index[:10])

def filter2(df,col):
    filtro = filter(df,col)
    data_filtered = df[df[col].isin(filtro)]
    return data_filtered

datacrash= filter2(datacrash,'new_column')

datacrash.head()
# Out:
#           Date   Time                            Location  \
# 2   08/06/1913    NaN  Victoria, British Columbia, Canada
# 8   09/24/1916  01:00                 Billericay, England
# 9   10/01/1916  23:45                Potters Bar, England
# 11  11/28/1916  23:45        Off West Hartlepool, England
# 17  10/20/1917  07:45              Near Luneville, France
#
#                   Operator Flight # Route                     Type  \
# 2                  Private        -   NaN         Curtiss seaplane
# 8   Military - German Navy      NaN   NaN  Zeppelin L-32 (airship)
# 9   Military - German Navy      NaN   NaN  Zeppelin L-31 (airship)
# 11  Military - German Navy      NaN   NaN  Zeppelin L-34 (airship)
# 17  Military - German Navy      NaN   NaN  Zeppelin L-44 (airship)
#
#    Registration cn/In  Aboard  Fatalities  Ground  \
# 2           NaN   NaN     1.0         1.0     0.0
# 8           NaN   NaN    22.0        22.0     0.0
# 9           NaN   NaN    19.0        19.0     0.0
# 11          NaN   NaN    20.0        20.0     0.0
# 17          NaN   NaN    18.0        18.0     0.0
#
#                                               Summary new_column  \
# 2   The first fatal airplane accident in Canada oc...     Canada
# 8   Shot down by British aircraft crashing in flames.    England
# 9   Shot down in flames by the British 39th Home D...    England
# 11  Shot down by British anti-aircraft fire and ai...    England
# 17            Shot down by French anti-aircraft fire.     France
#
#             new_column2  percent
# 2              Victoria    100.0
# 8            Billericay    100.0
# 9           Potters Bar    100.0
# 11  Off West Hartlepool    100.0
# 17       Near Luneville    100.0

# %%
def filtered():
    df=
