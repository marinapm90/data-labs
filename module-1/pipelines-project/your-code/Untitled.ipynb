# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

""" La función  load_data sirve para cargar el csv

"""

def load_data(file):
    df = pd.read_csv(file)
    return df

datacrash = load_data('Airplane_Crashes.csv')

datacrash.head()
# Out:
#          Date   Time                            Location  \
# 0  09/17/1908  17:18                 Fort Myer, Virginia
# 1  07/12/1912  06:30             AtlantiCity, New Jersey
# 2  08/06/1913    NaN  Victoria, British Columbia, Canada
# 3  09/09/1913  18:30                  Over the North Sea
# 4  10/17/1913  10:30          Near Johannisthal, Germany
#
#                  Operator Flight #          Route                    Type  \
# 0    Military - U.S. Army      NaN  Demonstration        Wright Flyer III
# 1    Military - U.S. Navy      NaN    Test flight               Dirigible
# 2                 Private        -            NaN        Curtiss seaplane
# 3  Military - German Navy      NaN            NaN  Zeppelin L-1 (airship)
# 4  Military - German Navy      NaN            NaN  Zeppelin L-2 (airship)
#
#   Registration cn/In  Aboard  Fatalities  Ground  \
# 0          NaN     1     2.0         1.0     0.0
# 1          NaN   NaN     5.0         5.0     0.0
# 2          NaN   NaN     1.0         1.0     0.0
# 3          NaN   NaN    20.0        14.0     0.0
# 4          NaN   NaN    30.0        30.0     0.0
#
#                                              Summary
# 0  During a demonstration flight, a U.S. Army fly...
# 1  First U.S. dirigible Akron exploded just offsh...
# 2  The first fatal airplane accident in Canada oc...
# 3  The airship flew into a thunderstorm and encou...
# 4  Hydrogen gas which was being vented was sucked...

# %%
def drop_null(df,percent):
    for column in df:
        result = (df[column].isnull().sum()/len(df))
        if result >= percent:
            del df[column]    
    return df
        
datacrash = drop_null(datacrash,0.75)
datacrash.head()
# Out:
#          Date   Time                            Location  \
# 0  09/17/1908  17:18                 Fort Myer, Virginia
# 1  07/12/1912  06:30             AtlantiCity, New Jersey
# 2  08/06/1913    NaN  Victoria, British Columbia, Canada
# 3  09/09/1913  18:30                  Over the North Sea
# 4  10/17/1913  10:30          Near Johannisthal, Germany
#
#                  Operator          Route                    Type Registration  \
# 0    Military - U.S. Army  Demonstration        Wright Flyer III          NaN
# 1    Military - U.S. Navy    Test flight               Dirigible          NaN
# 2                 Private            NaN        Curtiss seaplane          NaN
# 3  Military - German Navy            NaN  Zeppelin L-1 (airship)          NaN
# 4  Military - German Navy            NaN  Zeppelin L-2 (airship)          NaN
#
#   cn/In  Aboard  Fatalities  Ground  \
# 0     1     2.0         1.0     0.0
# 1   NaN     5.0         5.0     0.0
# 2   NaN     1.0         1.0     0.0
# 3   NaN    20.0        14.0     0.0
# 4   NaN    30.0        30.0     0.0
#
#                                              Summary
# 0  During a demonstration flight, a U.S. Army fly...
# 1  First U.S. dirigible Akron exploded just offsh...
# 2  The first fatal airplane accident in Canada oc...
# 3  The airship flew into a thunderstorm and encou...
# 4  Hydrogen gas which was being vented was sucked...

# %%
def split_column(df,col):
    df['new_column'] = df[col].str.split(',').str[-1]
    df['new_column2'] = df[col].str.split(',').str[0]
    return df

datacrash = split_column(datacrash,'Location')

datacrash.head()
# Out:
#          Date   Time                            Location  \
# 0  09/17/1908  17:18                 Fort Myer, Virginia
# 1  07/12/1912  06:30             AtlantiCity, New Jersey
# 2  08/06/1913    NaN  Victoria, British Columbia, Canada
# 3  09/09/1913  18:30                  Over the North Sea
# 4  10/17/1913  10:30          Near Johannisthal, Germany
#
#                  Operator          Route                    Type Registration  \
# 0    Military - U.S. Army  Demonstration        Wright Flyer III          NaN
# 1    Military - U.S. Navy    Test flight               Dirigible          NaN
# 2                 Private            NaN        Curtiss seaplane          NaN
# 3  Military - German Navy            NaN  Zeppelin L-1 (airship)          NaN
# 4  Military - German Navy            NaN  Zeppelin L-2 (airship)          NaN
#
#   cn/In  Aboard  Fatalities  Ground  \
# 0     1     2.0         1.0     0.0
# 1   NaN     5.0         5.0     0.0
# 2   NaN     1.0         1.0     0.0
# 3   NaN    20.0        14.0     0.0
# 4   NaN    30.0        30.0     0.0
#
#                                              Summary          new_column  \
# 0  During a demonstration flight, a U.S. Army fly...            Virginia
# 1  First U.S. dirigible Akron exploded just offsh...          New Jersey
# 2  The first fatal airplane accident in Canada oc...              Canada
# 3  The airship flew into a thunderstorm and encou...  Over the North Sea
# 4  Hydrogen gas which was being vented was sucked...             Germany
#
#           new_column2
# 0           Fort Myer
# 1         AtlantiCity
# 2            Victoria
# 3  Over the North Sea
# 4   Near Johannisthal

# %%
def rename_col(df,col,new_name):
    df.rename(columns = { col: new_name}, inplace = True)
    return df

datacrash = rename_col(datacrash,'new_column','Country')
datacrash = rename_col(datacrash,'new_column2','Regions')
datacrash.head()
# Out:
#          Date   Time                            Location  \
# 0  09/17/1908  17:18                 Fort Myer, Virginia
# 1  07/12/1912  06:30             AtlantiCity, New Jersey
# 2  08/06/1913    NaN  Victoria, British Columbia, Canada
# 3  09/09/1913  18:30                  Over the North Sea
# 4  10/17/1913  10:30          Near Johannisthal, Germany
#
#                  Operator          Route                    Type Registration  \
# 0    Military - U.S. Army  Demonstration        Wright Flyer III          NaN
# 1    Military - U.S. Navy    Test flight               Dirigible          NaN
# 2                 Private            NaN        Curtiss seaplane          NaN
# 3  Military - German Navy            NaN  Zeppelin L-1 (airship)          NaN
# 4  Military - German Navy            NaN  Zeppelin L-2 (airship)          NaN
#
#   cn/In  Aboard  Fatalities  Ground  \
# 0     1     2.0         1.0     0.0
# 1   NaN     5.0         5.0     0.0
# 2   NaN     1.0         1.0     0.0
# 3   NaN    20.0        14.0     0.0
# 4   NaN    30.0        30.0     0.0
#
#                                              Summary             Country  \
# 0  During a demonstration flight, a U.S. Army fly...            Virginia
# 1  First U.S. dirigible Akron exploded just offsh...          New Jersey
# 2  The first fatal airplane accident in Canada oc...              Canada
# 3  The airship flew into a thunderstorm and encou...  Over the North Sea
# 4  Hydrogen gas which was being vented was sucked...             Germany
#
#               Regions
# 0           Fort Myer
# 1         AtlantiCity
# 2            Victoria
# 3  Over the North Sea
# 4   Near Johannisthal

# %%
def percent(df,col,column):
    df['percent'] = ((df[col]/df[column])*100)
    return df

datacrash = percent(datacrash,'Fatalities','Aboard')

datacrash.head()
# Out:
#          Date   Time                            Location  \
# 0  09/17/1908  17:18                 Fort Myer, Virginia
# 1  07/12/1912  06:30             AtlantiCity, New Jersey
# 2  08/06/1913    NaN  Victoria, British Columbia, Canada
# 3  09/09/1913  18:30                  Over the North Sea
# 4  10/17/1913  10:30          Near Johannisthal, Germany
#
#                  Operator          Route                    Type Registration  \
# 0    Military - U.S. Army  Demonstration        Wright Flyer III          NaN
# 1    Military - U.S. Navy    Test flight               Dirigible          NaN
# 2                 Private            NaN        Curtiss seaplane          NaN
# 3  Military - German Navy            NaN  Zeppelin L-1 (airship)          NaN
# 4  Military - German Navy            NaN  Zeppelin L-2 (airship)          NaN
#
#   cn/In  Aboard  Fatalities  Ground  \
# 0     1     2.0         1.0     0.0
# 1   NaN     5.0         5.0     0.0
# 2   NaN     1.0         1.0     0.0
# 3   NaN    20.0        14.0     0.0
# 4   NaN    30.0        30.0     0.0
#
#                                              Summary             Country  \
# 0  During a demonstration flight, a U.S. Army fly...            Virginia
# 1  First U.S. dirigible Akron exploded just offsh...          New Jersey
# 2  The first fatal airplane accident in Canada oc...              Canada
# 3  The airship flew into a thunderstorm and encou...  Over the North Sea
# 4  Hydrogen gas which was being vented was sucked...             Germany
#
#               Regions  percent
# 0           Fort Myer     50.0
# 1         AtlantiCity    100.0
# 2            Victoria    100.0
# 3  Over the North Sea     70.0
# 4   Near Johannisthal    100.0

# %%
def filter(df,col):
    crashes = df[col].value_counts()
    return (crashes.index[:10])

def filter2(df,col):
    filtro = filter(df,col)
    data_filtered = df[df[col].isin(filtro)]
    return data_filtered

datacrash= filter2(datacrash,'Country')

datacrash.head()
# Out:
#           Date   Time                            Location  \
# 2   08/06/1913    NaN  Victoria, British Columbia, Canada
# 8   09/24/1916  01:00                 Billericay, England
# 9   10/01/1916  23:45                Potters Bar, England
# 11  11/28/1916  23:45        Off West Hartlepool, England
# 17  10/20/1917  07:45              Near Luneville, France
#
#                   Operator Route                     Type Registration cn/In  \
# 2                  Private   NaN         Curtiss seaplane          NaN   NaN
# 8   Military - German Navy   NaN  Zeppelin L-32 (airship)          NaN   NaN
# 9   Military - German Navy   NaN  Zeppelin L-31 (airship)          NaN   NaN
# 11  Military - German Navy   NaN  Zeppelin L-34 (airship)          NaN   NaN
# 17  Military - German Navy   NaN  Zeppelin L-44 (airship)          NaN   NaN
#
#     Aboard  Fatalities  Ground  \
# 2      1.0         1.0     0.0
# 8     22.0        22.0     0.0
# 9     19.0        19.0     0.0
# 11    20.0        20.0     0.0
# 17    18.0        18.0     0.0
#
#                                               Summary   Country  \
# 2   The first fatal airplane accident in Canada oc...    Canada
# 8   Shot down by British aircraft crashing in flames.   England
# 9   Shot down in flames by the British 39th Home D...   England
# 11  Shot down by British anti-aircraft fire and ai...   England
# 17            Shot down by French anti-aircraft fire.    France
#
#                 Regions  percent
# 2              Victoria    100.0
# 8            Billericay    100.0
# 9           Potters Bar    100.0
# 11  Off West Hartlepool    100.0
# 17       Near Luneville    100.0

# %%
def change_null(df):
    return df.fillna('-')

datacrash = change_null(datacrash)
datacrash.head()
# Out:
#           Date   Time                            Location  \
# 2   08/06/1913      -  Victoria, British Columbia, Canada
# 8   09/24/1916  01:00                 Billericay, England
# 9   10/01/1916  23:45                Potters Bar, England
# 11  11/28/1916  23:45        Off West Hartlepool, England
# 17  10/20/1917  07:45              Near Luneville, France
#
#                   Operator Route                     Type Registration cn/In  \
# 2                  Private     -         Curtiss seaplane            -     -
# 8   Military - German Navy     -  Zeppelin L-32 (airship)            -     -
# 9   Military - German Navy     -  Zeppelin L-31 (airship)            -     -
# 11  Military - German Navy     -  Zeppelin L-34 (airship)            -     -
# 17  Military - German Navy     -  Zeppelin L-44 (airship)            -     -
#
#    Aboard Fatalities Ground  \
# 2       1          1      0
# 8      22         22      0
# 9      19         19      0
# 11     20         20      0
# 17     18         18      0
#
#                                               Summary   Country  \
# 2   The first fatal airplane accident in Canada oc...    Canada
# 8   Shot down by British aircraft crashing in flames.   England
# 9   Shot down in flames by the British 39th Home D...   England
# 11  Shot down by British anti-aircraft fire and ai...   England
# 17            Shot down by French anti-aircraft fire.    France
#
#                 Regions percent
# 2              Victoria     100
# 8            Billericay     100
# 9           Potters Bar     100
# 11  Off West Hartlepool     100
# 17       Near Luneville     100

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-8524b1d1e9f0> in <module>
# ----> 1 datacrash.plot.bar('Country')
#
# /usr/lib/python3/dist-packages/pandas/plotting/_core.py in bar(self, x, y, **kwds)
#    2714         axes : matplotlib.AxesSubplot or np.array of them
#    2715         """
# -> 2716         return self(kind='bar', x=x, y=y, **kwds)
#    2717
#    2718     def barh(self, x=None, y=None, **kwds):
#
# /usr/lib/python3/dist-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2675                           fontsize=fontsize, colormap=colormap, table=table,
#    2676                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2677                           sort_columns=sort_columns, **kwds)
#    2678     __call__.__doc__ = plot_frame.__doc__
#    2679
#
# /usr/lib/python3/dist-packages/pandas/plotting/_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1900                  yerr=yerr, xerr=xerr,
#    1901                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1902                  **kwds)
#    1903
#    1904
#
# /usr/lib/python3/dist-packages/pandas/plotting/_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1727         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1728
# -> 1729     plot_obj.generate()
#    1730     plot_obj.draw()
#    1731     return plot_obj.result
#
# /usr/lib/python3/dist-packages/pandas/plotting/_core.py in generate(self)
#     248     def generate(self):
#     249         self._args_adjust()
# --> 250         self._compute_plot_data()
#     251         self._setup_subplots()
#     252         self._make_plot()
#
# /usr/lib/python3/dist-packages/pandas/plotting/_core.py in _compute_plot_data(self)
#     363         if is_empty:
#     364             raise TypeError('Empty {0!r}: no numeric data to '
# --> 365                             'plot'.format(numeric_data.__class__.__name__))
#     366
#     367         self.data = numeric_data
#
# TypeError: Empty 'DataFrame': no numeric data to plot
